# %%
# !pip install pandas

# %%
import pandas as pd
from pycaret.regression import *

# %%
data = pd.read_csv("datasets/insurance_charges.csv")
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
save_model("dt_insurance_charges")

# %%
deloy_insurance_charges = load_model('dt_insurance_charges')
deploy_insurance_charges
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 deloy_insurance_chages = load_model('dt_insurance_charges')
#
# File ~\anaconda3\envs\predictenv1\lib\site-packages\pycaret\regression\functional.py:2162, in load_model(model_name, platform, authentication, verbose)
#    2159 if experiment is None:
#    2160     experiment = _EXPERIMENT_CLASS()
# -> 2162 return experiment.load_model(
#    2163     model_name=model_name,
#    2164     platform=platform,
#    2165     authentication=authentication,
#    2166     verbose=verbose,
#    2167 )
#
# File ~\anaconda3\envs\predictenv1\lib\site-packages\pycaret\regression\oop.py:2451, in RegressionExperiment.load_model(self, model_name, platform, authentication, verbose)
#    2404 def load_model(
#    2405     self,
#    2406     model_name: str,
#    (...)
#    2409     verbose: bool = True,
#    2410 ):
# ...

# %%
de
